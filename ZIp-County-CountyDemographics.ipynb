# %%
#Add Dependencies
import pandas as pd
import numpy as np
# import psycopg2 as pg
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
county_demo = "Data/cc-est2019-agesex-06.csv"
zip_codes = "Data/zip-county.csv"
county_names = "Data/all-geocodes-v2018.xlsx"
write_file = "Data/zipcode_county_demographics.csv"

# %%
# Import our input dataset
zipcode_df = pd.read_csv(zip_codes , low_memory=False, index_col=False)

# %%
#Check imported Dataset
zipcode_df.head()
# Out:
#    COUNTY    ZIP
# 0    1001  36068
# 1    1001  36067
# 2    1001  36008
# 3    1001  36758
# 4    1001  36051

# %%
# Import our input dataset
countyd_df = pd.read_csv(county_demo , dtype=str, low_memory=False, index_col=False)

# %%
countyd_df.head()
# Out:
#   SUMLEV STATE COUNTY      STNAME         CTYNAME YEAR POPESTIMATE  \
# 0    050    06    001  California  Alameda County    1     1510271
# 1    050    06    001  California  Alameda County    2     1510258
# 2    050    06    001  California  Alameda County    3     1512986
# 3    050    06    001  California  Alameda County    4     1530915
# 4    050    06    001  California  Alameda County    5     1553764
#
#   POPEST_MALE POPEST_FEM UNDER5_TOT  ... AGE7579_FEM AGE8084_TOT AGE8084_MALE  \
# 0      740573     769698      97652  ...       16568       23391         9144
# 1      740568     769690      97650  ...       16568       23391         9144
# 2      741756     771230      97656  ...       16597       23339         9173
# 3      750107     780808      97776  ...       16898       23210         9240
# 4      760739     793025      97500  ...       17240       23271         9362
#
#   AGE8084_FEM AGE85PLUS_TOT AGE85PLUS_MALE AGE85PLUS_FEM MEDIAN_AGE_TOT  \
# ...

# %%
countyd_df = countyd_df.loc[countyd_df['YEAR'] == "12"]

# %%
countyd_df.head()
# Out:
#    SUMLEV STATE COUNTY      STNAME           CTYNAME YEAR POPESTIMATE  \
# 11    050    06    001  California    Alameda County   12     1671329
# 23    050    06    003  California     Alpine County   12        1129
# 35    050    06    005  California     Amador County   12       39752
# 47    050    06    007  California      Butte County   12      219186
# 59    050    06    009  California  Calaveras County   12       45905
#
#    POPEST_MALE POPEST_FEM UNDER5_TOT  ... AGE7579_FEM AGE8084_TOT  \
# 11      823247     848082      94728  ...       22227       26863
# 23         609        520         49  ...          23          24
# 35       21638      18114       1612  ...        1017        1231
# 47      108473     110713      12062  ...        3702        4565
# 59       22847      23058       2055  ...        1203        1513
#
#    AGE8084_MALE AGE8084_FEM AGE85PLUS_TOT AGE85PLUS_MALE AGE85PLUS_FEM  \
# 11        11364       15499         31209          11148         20061
# ...

# %%
countyd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58 entries, 11 to 695
# Data columns (total 96 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   SUMLEV           58 non-null     object
#  1   STATE            58 non-null     object
#  2   COUNTY           58 non-null     object
#  3   STNAME           58 non-null     object
#  4   CTYNAME          58 non-null     object
#  5   YEAR             58 non-null     object
#  6   POPESTIMATE      58 non-null     object
#  7   POPEST_MALE      58 non-null     object
#  8   POPEST_FEM       58 non-null     object
#  9   UNDER5_TOT       58 non-null     object
#  10  UNDER5_MALE      58 non-null     object
#  11  UNDER5_FEM       58 non-null     object
#  12  AGE513_TOT       58 non-null     object
#  13  AGE513_MALE      58 non-null     object
#  14  AGE513_FEM       58 non-null     object
#  15  AGE1417_TOT      58 non-null     object
# ...

# %%
columns_demo = ["STATE", "COUNTY", "STNAME", "CTYNAME", "POPESTIMATE", "POPEST_MALE", "POPEST_FEM", "MEDIAN_AGE_TOT", "MEDIAN_AGE_MALE", "MEDIAN_AGE_FEM" ]

# %%
countydemo_df=countyd_df[columns_demo]

# %%
countydemo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58 entries, 11 to 695
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   STATE            58 non-null     object
#  1   COUNTY           58 non-null     object
#  2   STNAME           58 non-null     object
#  3   CTYNAME          58 non-null     object
#  4   POPESTIMATE      58 non-null     object
#  5   POPEST_MALE      58 non-null     object
#  6   POPEST_FEM       58 non-null     object
#  7   MEDIAN_AGE_TOT   58 non-null     object
#  8   MEDIAN_AGE_MALE  58 non-null     object
#  9   MEDIAN_AGE_FEM   58 non-null     object
# dtypes: object(10)
# memory usage: 5.0+ KB

# %%
countydemo_df["FIPS"]= countydemo_df['STATE'] + countydemo_df['COUNTY']
# Out:
# /Users/will/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
countydemo_df
# Out:
#     STATE COUNTY      STNAME                 CTYNAME POPESTIMATE POPEST_MALE  \
# 11     06    001  California          Alameda County     1671329      823247
# 23     06    003  California           Alpine County        1129         609
# 35     06    005  California           Amador County       39752       21638
# 47     06    007  California            Butte County      219186      108473
# 59     06    009  California        Calaveras County       45905       22847
# 71     06    011  California           Colusa County       21547       10975
# 83     06    013  California     Contra Costa County     1153526      564187
# 95     06    015  California        Del Norte County       27812       15186
# 107    06    017  California        El Dorado County      192843       96158
# 119    06    019  California           Fresno County      999101      498648
# 131    06    021  California            Glenn County       28393       14462
# ...

# %%
# Import our input dataset
zipcode_df = pd.read_csv(zip_codes , low_memory=False, index_col=False)

# %%
zip_df['ZIP'] = zip_df['ZIP'].astype('str')

# %%
zip_df['COUNTY'] = zip_df['COUNTY'].astype('str')

# %%
zip_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54197 entries, 0 to 54196
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   COUNTY  54197 non-null  object
#  1   ZIP     54197 non-null  object
# dtypes: object(2)
# memory usage: 847.0+ KB

# %%
combined_df = pd.merge(staff_df, zip_df, how='left', left_on='ZIP', right_on='ZIP' )

# %%
combined_df
# Out:
#      Badge ID  BirthYear  BirthMonth  BirthDay  Age                 City  \
# 0      S00685       1983           8        21   34        San Francisco
# 1      S03759       1989           8        25   29          Foster City
# 2      S01895       1982           6        30   36               Irvine
# 3      S00066       1985           8        30   33          Los Angeles
# 4      S02172       1991           4         2   28              Hayward
# ...       ...        ...         ...       ...  ...                  ...
# 9231    S5167          0           0         0   51            Sunnyvale
# 9232    S5165       1967          10        28   45  South San Francisco
# 9233    S5853       1980          12        10   32           Sacramento
# 9234    S4963       1974           3        11   39              Fremont
# 9235    S5014          0           0         0    0        San Francisco
#
#      State    Zip Country           Division                Department  Year  \
# ...

# %%
combined_df=combined_df.dropna()

# %%
#Export dataset to CSV
combined_df.to_csv(write_file)
